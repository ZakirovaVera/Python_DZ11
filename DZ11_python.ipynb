# %% [markdown]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np

# %%
x = sympy.symbols('x')

# %% [markdown]
# 4. Построить графикк

# %%
x = np.arange(-10, 10, 0.01)
f = -12*x**4*np.sin(np.cos(x)) - 18*x**3+5*x**2 + 10*x - 30
plt.plot(x, f, 'r')
f2 = 0*x
plt.plot(x, f2,'b')
plt.show()

# %% [markdown]
# 1. Корни уравнения при х(-10, 10) точки пересечения с прямой (синяя линия)

# %% [markdown]
# При х(-10, 10)
#
# 6. Промежутки, на котором f > 0 (-10, -8) и (-5, -2) и (2, 4) и (8,5, 10)
#
# 7. Промежутки, на котором f < 0 (-8,5, -5) и (4, 8,5)

# %% [markdown]
# При х(-10, 10)
#
# 2. Интервалы, на которых функция возрастает (-7, -4) и (0, 4) и (7, 9,5)
#
# 3. Интервалы, на которых функция убывает (-10, -7) и (-4, 0) и (4, 7) и (9,5, 10)
#
# При х=7 минимум
#
# При х=-10 максимум

# %% [markdown]
# 5. Вершина при х(-10, 10)
#
# По графику две вершины при х=-10, при х=9,5
